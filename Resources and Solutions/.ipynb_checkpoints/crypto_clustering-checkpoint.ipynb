# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Load in the provided .csv file and create a DataFrame
crypto_path = Path('/Users', 'tylerhubbard', 'umnfintech', 'AWS_HW', 'Resources and Solutions', 'crypto_data.csv')

crypto_df = pd.read_csv(crypto_path, index_col=0)
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]
crypto_df.head(15)
# Out:
#               CoinName       Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt       True   PoW/PoS     4.199995e+01
# 365            365Coin             X11       True   PoW/PoS              NaN
# 404            404Coin          Scrypt       True   PoW/PoS     1.055185e+09
# 611          SixEleven         SHA-256       True       PoW              NaN
# 808                808         SHA-256       True   PoW/PoS     0.000000e+00
# 1337         EliteCoin             X13       True   PoW/PoS     2.927942e+10
# 2015         2015 coin             X11       True   PoW/PoS              NaN
# BTC            Bitcoin         SHA-256       True       PoW     1.792718e+07
# ETH           Ethereum          Ethash       True       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       True       PoW     6.303924e+07
# DASH              Dash             X11       True   PoW/PoS     9.031294e+06
# ...

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df.loc[crypto_df['Algorithm'] != 'N/A']

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns=['IsTrading'])
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 365       365Coin          X11   PoW/PoS              NaN      2300000000
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 611     SixEleven      SHA-256       PoW              NaN          611000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# SERO   Super Zero       Ethash       PoW              NaN      1000000000
# UOS           UOS      SHA-256      DPoI              NaN      1000000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna()
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df['TotalCoinsMined'] > 0]
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df.iloc[:] != 'N/A'].dropna()
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df using .to_frame()
coinname_df = crypto_df['CoinName'].to_frame()
coinname_df.set_index(crypto_df.index)
coinname_df.head(10)
# Out:
#               CoinName
# 42             42 Coin
# 404            404Coin
# 1337         EliteCoin
# BTC            Bitcoin
# ETH           Ethereum
# LTC           Litecoin
# DASH              Dash
# XMR             Monero
# ETC   Ethereum Classic
# ZEC              ZCash

# %%
# Drop the 'CoinName' column in the crypto_df since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns=['CoinName'])
crypto_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      Scrypt   PoW/PoS     4.199995e+01              42
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337       X13   PoW/PoS     2.927942e+10    314159265359
# BTC    SHA-256       PoW     1.792718e+07        21000000
# ETH     Ethash       PoW     1.076842e+08               0

# %%
# Create dummy variables for text features
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
X.head(10)
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# LTC      6.303924e+07        84000000                                 0
# DASH     9.031294e+06        22000000                                 0
# XMR      1.720114e+07               0                                 0
# ETC      1.133597e+08       210000000                                 0
# ZEC      7.383056e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# ...

# %%
# Standardize data
X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components using n_components
pca = PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
pca_array_df = pca.fit_transform(X_scaled)
pca_names_df = [f'PC {i}' for i in range(1,4)]
pca_df = pd.DataFrame(pca_array_df, columns=pca_names_df, index=crypto_df.index)

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pca_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_curve_data = {'k' : k, 'inertia' : inertia}
elbow_curve_df = pd.DataFrame(elbow_curve_data)
elbow_curve_plot = elbow_curve_df.hvplot.line(x='k', y='inertia', xticks=k, title='Elbow Curve')
elbow_curve_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pca_df)

# Predict clusters
cluster_prediction = model.predict(pca_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
crypto_clusters_df = pd.concat([crypto_df, pca_df], axis=1)
crypto_clusters_df['Class'] = model.labels_
crypto_clusters_df['CoinName'] = coinname_df['CoinName']
crypto_clusters_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1      PC 2  \
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.336443  0.950402
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.319767  0.950646
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  2.294896  1.735323
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.145700 -1.264056
# ETH     Ethash       PoW     1.076842e+08               0 -0.162511 -2.012514
#
#           PC 3  Class   CoinName
# 42   -0.319617      0    42 Coin
# 404  -0.319815      0    404Coin
# 1337 -0.406827      0  EliteCoin
# BTC   0.091936      3    Bitcoin
# ETH   0.239398      3   Ethereum

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
scaled_data = MinMaxScaler().fit_transform(crypto_clusters_df[['TotalCoinsMined', 'TotalCoinSupply']])
scaled_df = pd.DataFrame(scaled_data, columns=['TotalCoinsMined', 'TotalCoinSupply'], index=crypto_clusters_df.index)
scaled_df['Class'] = crypto_clusters_df['Class']
scaled_df.head(10)
# Out:
#       TotalCoinsMined  TotalCoinSupply  Class
# 42           0.000000     4.200000e-11      0
# 404          0.001066     5.320000e-04      0
# 1337         0.029576     3.141593e-01      0
# BTC          0.000018     2.100000e-05      3
# ETH          0.000109     0.000000e+00      3
# LTC          0.000064     8.400000e-05      3
# DASH         0.000009     2.200000e-05      0
# XMR          0.000017     0.000000e+00      3
# ETC          0.000115     2.100000e-04      3
# ZEC          0.000007     2.100000e-05      3

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
scatter_plot = scaled_df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply',
                                        hover_cols=['Class'], by=['Class'])
scatter_plot
# Out:
# :NdOverlay   [Class]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply,Class)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
tradable_crypto = crypto_clusters_df[['CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply', 'Class']]
tradable_crypto.hvplot.table()
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinsMined,TotalCoinSupply,Class]

# %%
# Print the total number of tradable cryptocurrencies
print(f'The total number of tradeable currencies is {tradable_crypto.shape[0]}.')
# Out:
# The total number of tradeable currencies is 532.
